# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv("https://www1.ncdc.noaa.gov/pub/orders/CDODiv4911488063101.txt")
df.head(10)
# Out:
#    StateCode  Division  YearMonth      PCP     TAVG     PDSI     PHDI  \
# 0        109         0     201401     0.53     44.8    -6.13    -6.13
# 1        109         0     201402     2.86     45.4    -6.36    -6.36
# 2        109         0     201403     2.35     49.3    -6.46    -6.46
# 3        109         0     201404     0.90     54.1    -6.43    -6.43
# 4        109         0     201405     0.54     61.6    -7.13    -7.13
# 5        109         0     201406     0.08     69.8    -8.10    -8.10
# 6        109         0     201407     0.45     77.4    -8.36    -8.36
# 7        109         0     201408     0.88     72.7    -7.27    -7.27
# 8        109         0     201409     0.91     69.5    -6.22    -6.22
# 9        109         0     201410     0.67     60.7    -6.09    -6.09
#
#       ZNDX     PMDI      CDD  ...     SP01     SP02     SP03     SP06  \
# 0    -5.73    -6.13       10  ...    -1.86    -2.47    -2.17    -2.15
# ...

# %%
data = df.StateCode.replace([109], ['West'], inplace=True)
data

# %%
# df["YearMonth"] =  pd.to_datetime(df["YearMonth"])
# df.dtypes

# %%
df['YearMonth'] = df['YearMonth'].apply(lambda cell: str(cell)[0:4] + '-' + str(cell)[4:6])
df['YearMonth'].head()
# Out:
# 0    2014-01
# 1    2014-02
# 2    2014-03
# 3    2014-04
# 4    2014-05
# Name: YearMonth, dtype: object

# %%
# cols= ['Divion','ZNDX','PMDI','CDD','HDD','SP01','SP02','SP03','SP06','SP09','SP12','SP24']
cols = df.iloc[:,[0,2,3,4,5,6,18,19]]
# west = df.drop(cols, axis=1)
cols.head(10)
# Out:
#   StateCode                     YearMonth      PCP     TAVG     PDSI     PHDI  \
# 0      West 1970-01-01 00:00:00.000201401     0.53     44.8    -6.13    -6.13
# 1      West 1970-01-01 00:00:00.000201402     2.86     45.4    -6.36    -6.36
# 2      West 1970-01-01 00:00:00.000201403     2.35     49.3    -6.46    -6.46
# 3      West 1970-01-01 00:00:00.000201404     0.90     54.1    -6.43    -6.43
# 4      West 1970-01-01 00:00:00.000201405     0.54     61.6    -7.13    -7.13
# 5      West 1970-01-01 00:00:00.000201406     0.08     69.8    -8.10    -8.10
# 6      West 1970-01-01 00:00:00.000201407     0.45     77.4    -8.36    -8.36
# 7      West 1970-01-01 00:00:00.000201408     0.88     72.7    -7.27    -7.27
# 8      West 1970-01-01 00:00:00.000201409     0.91     69.5    -6.22    -6.22
# 9      West 1970-01-01 00:00:00.000201410     0.67     60.7    -6.09    -6.09
#
#       TMIN     TMAX
# 0     31.9     57.6
# 1     34.4     56.5
# 2     37.0     61.6
# 3     40.4     67.8
# ...

# %%
cols = cols.rename(columns={"YearMonth": "Date","StateCode":"Region"})
cols.head(10)
# Out:
#   Region    Date      PCP     TAVG     PDSI     PHDI     TMIN     TMAX
# 0   West  201401     0.53     44.8    -6.13    -6.13     31.9     57.6
# 1   West  201402     2.86     45.4    -6.36    -6.36     34.4     56.5
# 2   West  201403     2.35     49.3    -6.46    -6.46     37.0     61.6
# 3   West  201404     0.90     54.1    -6.43    -6.43     40.4     67.8
# 4   West  201405     0.54     61.6    -7.13    -7.13     47.2     76.1
# 5   West  201406     0.08     69.8    -8.10    -8.10     54.1     85.4
# 6   West  201407     0.45     77.4    -8.36    -8.36     62.6     92.2
# 7   West  201408     0.88     72.7    -7.27    -7.27     58.6     86.8
# 8   West  201409     0.91     69.5    -6.22    -6.22     55.1     83.8
# 9   West  201410     0.67     60.7    -6.09    -6.09     46.4     75.0

# %%
# dti = pd.to_datetime(['201401', df.datetime('2014-01'),
#                      datetime.datetime(2014,1)])
dt = df['YearMonth'] = df['YearMonth'].datetime.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9a0dc489b32b> in <module>
#       1 # dti = pd.to_datetime(['201401', df.datetime('2014-01'),
#       2 #                      datetime.datetime(2014,1)])
# ----> 3 dt = df['YearMonth'] = df['YearMonth'].datetime.date
#
# C:\Users\IEshun\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5178             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5179                 return self[name]
# -> 5180             return object.__getattribute__(self, name)
#    5181
#    5182     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'datetime'

# %%
df['YearMonth'] =  pd.to_datetime(df['YearMonth'],format='%m%y')
df['YearMonth']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\IEshun\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     444             try:
# --> 445                 values, tz = conversion.datetime_to_datetime64(arg)
#     446                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-790c584cb9f2> in <module>
# ----> 1 df['YearMonth'] =  pd.to_datetime(df['YearMonth'],format='%m%y')
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\IEshun\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-b9c6864122be> in <module>
# ...

# %%
cols.to_csv('west.csv', index=False)
