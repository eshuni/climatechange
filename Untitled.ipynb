# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df1 = pd.read_csv("https://www1.ncdc.noaa.gov/pub/orders/CDODiv4745018061866.txt")

# %%
df1.head()
# Out:
#    StateCode  Division  YearMonth      PCP     TAVG     PDSI     PHDI  \
# 0        104         0     201401     3.21     40.0     2.52     2.52
# 1        104         0     201402     3.91     48.7     2.21     2.21
# 2        104         0     201403     4.64     51.6     2.09     2.09
# 3        104         0     201404     6.24     62.6     2.92     2.92
# 4        104         0     201405     4.15     70.7     0.03     2.65
#
#       ZNDX     PMDI      CDD  ...     SP01     SP02     SP03     SP06  \
# 0    -0.44     2.21       22  ...    -0.39     0.57     0.56    -0.05
# 1    -0.15     1.79       48  ...    -0.01    -0.33     0.42    -0.27
# 2     0.32     1.74       46  ...     0.14     0.08    -0.18     0.08
# 3     3.13     2.92       91  ...     1.79     1.24     0.95     0.95
# 4     0.09     2.62      228  ...     0.28     1.44     1.10     0.97
#
#       SP09     SP12     SP24     TMIN     TMAX  Unnamed: 20
# 0     1.31     1.40     0.75     28.3     51.7          NaN
# ...

# %%
df1.columns
# Out:
# Index(['StateCode', 'Division', 'YearMonth', '    PCP', '   TAVG', '   PDSI',
#        '   PHDI', '   ZNDX', '   PMDI', '    CDD', '    HDD', '   SP01',
#        '   SP02', '   SP03', '   SP06', '   SP09', '   SP12', '   SP24',
#        '   TMIN', '   TMAX', 'Unnamed: 20'],
#       dtype='object')

# %%
df1['YearMonth'] = df1['YearMonth'].apply(lambda cell: str(cell)[0:4] + '-' + str(cell)[4:6])
df1['YearMonth'].head()
# Out:
# 0    2014-01
# 1    2014-02
# 2    2014-03
# 3    2014-04
# 4    2014-05
# Name: YearMonth, dtype: object

# %%
df1.head()
# Out:
#    StateCode  Division YearMonth      PCP     TAVG     PDSI     PHDI     ZNDX  \
# 0        104         0   2014-01     3.21     40.0     2.52     2.52    -0.44
# 1        104         0   2014-02     3.91     48.7     2.21     2.21    -0.15
# 2        104         0   2014-03     4.64     51.6     2.09     2.09     0.32
# 3        104         0   2014-04     6.24     62.6     2.92     2.92     3.13
# 4        104         0   2014-05     4.15     70.7     0.03     2.65     0.09
#
#       PMDI      CDD  ...     SP01     SP02     SP03     SP06     SP09  \
# 0     2.21       22  ...    -0.39     0.57     0.56    -0.05     1.31
# 1     1.79       48  ...    -0.01    -0.33     0.42    -0.27     1.27
# 2     1.74       46  ...     0.14     0.08    -0.18     0.08     0.72
# 3     2.92       91  ...     1.79     1.24     0.95     0.95     0.50
# 4     2.62      228  ...     0.28     1.44     1.10     0.97     0.33
#
#       SP12     SP24     TMIN     TMAX  Unnamed: 20
# ...

# %%
_df = climate_data_df[['StateCode', 'YearMonth', 'PCP', 'TAVG', 'PDSI', 'PHDI', 'TMIN', 'TMAX']].copy()
ne_climate_data_df.head()

# %%
climate_df = cols.rename(columns={"YearMonth": "Date","StateCode":"Region"})
climate_df.head()
# Out:
#    Region    Date      PCP     TAVG     PDSI     PHDI     TMIN     TMAX
# 0     104  201401     3.21     40.0     2.52     2.52     28.3     51.7
# 1     104  201402     3.91     48.7     2.21     2.21     37.6     59.9
# 2     104  201403     4.64     51.6     2.09     2.09     39.4     63.7
# 3     104  201404     6.24     62.6     2.92     2.92     50.3     75.0
# 4     104  201405     4.15     70.7     0.03     2.65     58.8     82.6

# %%
#export to csv
climate_df.to_csv("./climate_df.csv",index=False)
