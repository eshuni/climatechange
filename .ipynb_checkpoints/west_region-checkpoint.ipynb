# 13    -0.38    -0.55    -1.65     36.7     61.2          NaN
# 14    -0.67    -1.02    -1.73     39.4     66.7          NaN
# 15    -0.79    -0.96    -1.69     39.0     67.0          NaN
# 16    -0.78    -0.70    -1.61     46.2     71.0          NaN
# 17    -0.92    -0.60    -1.61     57.8     88.1          NaN
# 18    -0.66    -0.48    -1.55     59.4     87.2          NaN
# 19    -0.59    -0.65    -1.66     59.9     89.9          NaN
# 20    -1.48    -0.82    -1.78     54.8     84.3          NaN
# 21    -0.60    -0.66    -1.51     48.9     73.8          NaN
# 22    -0.52    -0.63    -1.38     31.5     54.1          NaN
# 23     0.48    -0.90    -0.84     27.9     47.2          NaN
# 24     0.97     0.12    -0.20     30.2     47.8          NaN
# 25     0.29    -0.16    -0.47     33.6     58.6          NaN
# 26     0.57     0.53    -0.34     37.4     60.7          NaN
# 27     0.47     0.66    -0.22     42.1     67.3          NaN
# 28     0.48     0.55    -0.16     46.5     72.0          NaN
# 29     0.47     0.54    -0.11     56.4     87.4          NaN
# 30     0.40     0.38    -0.17     59.7     91.4          NaN
# 31     0.42     0.37    -0.27     58.9     90.2          NaN
# 32     0.22     0.36    -0.39     51.5     81.5          NaN
# 33     0.29     0.67    -0.03     45.2     69.7          NaN
# 34     0.82     0.64    -0.01     37.1     60.5          NaN
# 35     0.73     0.68    -0.15     28.0     48.2          NaN
# 36     1.65     1.28     0.90     28.3     45.2          NaN
# 37     2.12     2.18     1.33     34.9     52.1          NaN
# 38     1.79     1.76     1.54     37.9     62.4          NaN
# 39     1.86     1.76     1.68     39.7     64.5          NaN
# 40     1.79     1.71     1.57     46.7     75.0          NaN
# 41     1.78     1.68     1.56     55.9     86.2          NaN
# 42     1.52     1.71     1.49     62.4     93.1          NaN
# 43     1.63     1.74     1.51     61.4     90.7          NaN
# 44     1.63     1.77     1.56     52.8     80.2          NaN
# 45     0.74     1.41     1.40     42.1     72.3          NaN
# 46    -0.10     1.60     1.46     38.5     60.8          NaN
# 47    -0.98     0.98     1.07     29.5     55.0          NaN
# 48    -1.25    -0.11     0.75     34.2     54.9          NaN
# 49    -1.69    -1.49     0.65     28.7     53.7          NaN
# 50    -1.04    -0.92     0.71     33.9     56.2          NaN
# 51    -0.88    -1.02     0.72     40.9     67.5          NaN
# 52    -0.85    -0.87     0.76     47.7     73.9          NaN
# 53    -1.00    -0.94     0.73     54.3     85.5          NaN
# 54    -0.75    -0.90     0.78     63.5     93.5          NaN
# 55    -0.99    -1.00     0.79     59.8     90.3          NaN
# 56    -0.43    -1.20     0.74     52.8     84.4          NaN
# 57    -0.45    -1.01     0.42     43.7     69.4          NaN
# 58     0.41    -1.07     0.51     34.7     59.6          NaN
# 59    -0.51    -0.61     0.25     30.2     48.8          NaN
#
# [60 rows x 21 columns]

# %%
# df.dtypes

# %%
# cols= ['Divion','ZNDX','PMDI','CDD','HDD','SP01','SP02','SP03','SP06','SP09','SP12','SP24']
cols = df.iloc[:,[0,2,3,4,5,6,18,19]]
# west = df.drop(cols, axis=1)
cols.head(10)
# Out:
#    StateCode  YearMonth      PCP     TAVG     PDSI     PHDI     TMIN     TMAX
# 0        109     201401     0.53     44.8    -6.13    -6.13     31.9     57.6
# 1        109     201402     2.86     45.4    -6.36    -6.36     34.4     56.5
# 2        109     201403     2.35     49.3    -6.46    -6.46     37.0     61.6
# 3        109     201404     0.90     54.1    -6.43    -6.43     40.4     67.8
# 4        109     201405     0.54     61.6    -7.13    -7.13     47.2     76.1
# 5        109     201406     0.08     69.8    -8.10    -8.10     54.1     85.4
# 6        109     201407     0.45     77.4    -8.36    -8.36     62.6     92.2
# 7        109     201408     0.88     72.7    -7.27    -7.27     58.6     86.8
# 8        109     201409     0.91     69.5    -6.22    -6.22     55.1     83.8
# 9        109     201410     0.67     60.7    -6.09    -6.09     46.4     75.0

# %%
df['YearMonth'] =  pd.to_datetime(df['YearMonth'],format='%m%y')
df['YearMonth']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     444             try:
# --> 445                 values, tz = conversion.datetime_to_datetime64(arg)
#     446                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-790c584cb9f2> in <module>
# ----> 1 df['YearMonth'] =  pd.to_datetime(df['YearMonth'],format='%m%y')
#       2 df['YearMonth']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     773             result = arg.map(cache_array)
#     774         else:
# --> 775             values = convert_listlike(arg._values, True, format)
#     776             result = arg._constructor(values, index=arg.index, name=arg.name)
#     777     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     446                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     447             except (ValueError, TypeError):
# --> 448                 raise e
#     449
#     450     if result is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     411                 try:
#     412                     result, timezones = array_strptime(
# --> 413                         arg, format, exact=exact, errors=errors
#     414                     )
#     415                     if "%Z" in format or "%z" in format:
#
# pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: unconverted data remains: 401

# %%
cols = cols.rename(columns={"YearMonth": "Date","StateCode":"Region"})
cols.head(10)
# Out:
#    Region    Date      PCP     TAVG     PDSI     PHDI     TMIN     TMAX
# 0     109  201401     0.53     44.8    -6.13    -6.13     31.9     57.6
# 1     109  201402     2.86     45.4    -6.36    -6.36     34.4     56.5
# 2     109  201403     2.35     49.3    -6.46    -6.46     37.0     61.6
# 3     109  201404     0.90     54.1    -6.43    -6.43     40.4     67.8
# 4     109  201405     0.54     61.6    -7.13    -7.13     47.2     76.1
# 5     109  201406     0.08     69.8    -8.10    -8.10     54.1     85.4
# 6     109  201407     0.45     77.4    -8.36    -8.36     62.6     92.2
# 7     109  201408     0.88     72.7    -7.27    -7.27     58.6     86.8
# 8     109  201409     0.91     69.5    -6.22    -6.22     55.1     83.8
# 9     109  201410     0.67     60.7    -6.09    -6.09     46.4     75.0

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-b9c6864122be> in <module>
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2973             if self.columns.nlevels > 1:
#    2974                 return self._getitem_multilevel(key)
# -> 2975             indexer = self.columns.get_loc(key)
#    2976             if is_integer(indexer):
#    2977                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
# -> 2892                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2893         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2894         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
